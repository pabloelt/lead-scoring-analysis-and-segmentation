# %% [markdown]
# # MODELIZACIÓN PARA NO SUPERVISADO

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

from sklearn.model_selection import GridSearchCV

#Autocompletar rápido
# %config IPCompleter.greedy=True

#Desactivar la notación científica
pd.options.display.float_format = '{:.2f}'.format

#Desactivar los warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/pelop/OneDrive/Desktop/Curso Data Science Pedro/2 CURSO DATA SCIENCE/03_MACHINE_LEARNING/07_CASOS/01_LEADSCORING'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_df = 'df_tablon.pickle'

# %% [markdown]
# Cargar los datos.

# %%
df = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_df)
df
# Out:
#         origen_API  origen_Landing Page Submission  origen_Lead Add Form  \
# id
# 660737        1.00                            0.00                  0.00
# 660728        1.00                            0.00                  0.00
# 660727        0.00                            1.00                  0.00
# 660719        0.00                            1.00                  0.00
# 660673        0.00                            1.00                  0.00
# ...            ...                             ...                   ...
# 579697        0.00                            1.00                  0.00
# 579642        0.00                            1.00                  0.00
# 579615        0.00                            1.00                  0.00
# 579546        0.00                            1.00                  0.00
# 579538        0.00                            1.00                  0.00
#
#         origen_OTROS  fuente_Chat  fuente_Direct Traffic  fuente_Google  \
# id
# 660737          0.00         1.00                   0.00           0.00
# 660728          0.00         0.00                   0.00           0.00
# 660727          0.00         0.00                   1.00           0.00
# 660719          0.00         0.00                   1.00           0.00
# 660673          0.00         0.00                   0.00           1.00
# ...              ...          ...                    ...            ...
# 579697          0.00         0.00                   0.00           1.00
# 579642          0.00         0.00                   1.00           0.00
# 579615          0.00         0.00                   1.00           0.00
# 579546          0.00         0.00                   1.00           0.00
# 579538          0.00         0.00                   0.00           1.00
#
#         fuente_OTROS  fuente_Organic Search  fuente_Reference  ...  \
# id                                                             ...
# 660737          0.00                   0.00              0.00  ...
# 660728          0.00                   1.00              0.00  ...
# 660727          0.00                   0.00              0.00  ...
# 660719          0.00                   0.00              0.00  ...
# 660673          0.00                   0.00              0.00  ...
# ...              ...                    ...               ...  ...
# 579697          0.00                   0.00              0.00  ...
# 579642          0.00                   0.00              0.00  ...
# 579615          0.00                   0.00              0.00  ...
# 579546          0.00                   0.00              0.00  ...
# 579538          0.00                   0.00              0.00  ...
#
#         ocupacion_Unemployed  ocupacion_Working Professional  descarga_lm_No  \
# id
# 660737                  1.00                            0.00            1.00
# 660728                  1.00                            0.00            1.00
# 660727                  0.00                            0.00            0.00
# 660719                  1.00                            0.00            1.00
# 660673                  1.00                            0.00            1.00
# ...                      ...                             ...             ...
# 579697                  1.00                            0.00            1.00
# 579642                  1.00                            0.00            0.00
# 579615                  1.00                            0.00            1.00
# 579546                  1.00                            0.00            0.00
# 579538                  1.00                            0.00            1.00
#
#         descarga_lm_Yes  visitas_total_mms  tiempo_en_site_total_mms  \
# id
# 660737             0.00               0.00                      0.00
# 660728             0.00               0.10                      0.30
# 660727             1.00               0.04                      0.67
# 660719             0.00               0.02                      0.13
# 660673             0.00               0.04                      0.72
# ...                 ...                ...                       ...
# 579697             0.00               0.16                      0.45
# 579642             1.00               0.04                      0.78
# 579615             0.00               0.10                      0.09
# 579546             1.00               0.04                      0.10
# 579538             0.00               0.06                      0.22
#
#         paginas_vistas_visita_mms  score_actividad_mms  score_perfil_mms  \
# id
# 660737                       0.00                 0.73              0.44
# 660728                       0.12                 0.73              0.44
# 660727                       0.10                 0.64              1.00
# 660719                       0.05                 0.55              0.67
# 660673                       0.10                 0.64              1.00
# ...                           ...                  ...               ...
# 579697                       0.20                 0.73              1.00
# 579642                       0.10                 0.64              1.00
# 579615                       0.12                 0.64              1.00
# 579546                       0.10                 0.64              0.89
# 579538                       0.15                 0.73              0.56
#
#         compra
# id
# 660737       0
# 660728       0
# 660727       1
# 660719       0
# 660673       1
# ...        ...
# 579697       1
# 579642       0
# 579615       1
# 579546       0
# 579538       1
#
# [4873 rows x 42 columns]

# %% [markdown]
# ## MODELIZAR

# %% [markdown]
# ### Crear el espacio de soluciones

# %%
min_k = 3
max_k = 7

soluciones = list(range(min_k,max_k))

# %% [markdown]
# ### Crear listas para guardar la salida de cada métrica

# %%
codo = []
silueta = []
calins = []
davies = []

# %% [markdown]
# ### Analizar el espacio de soluciones

# %%
for solucion in soluciones:
    
    #Instanciar
    cluster = KMeans(n_clusters = solucion, n_init=10)
    
    #Entrenar
    cluster.fit(df)
    
    #Recoger las métricas
    codo.append(cluster.inertia_)
    silueta.append(silhouette_score(df, cluster.labels_))
    calins.append(calinski_harabasz_score(df, cluster.labels_))
    davies.append(davies_bouldin_score(df, cluster.labels_))

# %% [markdown]
# ### Identificar la mejor solucion

# %% [markdown]
# #### Analizar las métricas

# %%
metricas = pd.DataFrame({'Solucion':soluciones,
              'Codo': codo,
              'Silueta':silueta,
              'Calins':calins,           
              'Davies':davies}).set_index('Solucion')

metricas
# Out:
#              Codo  Silueta  Calins  Davies
# Solucion
# 3        13216.21     0.19 1005.62    2.07
# 4        12452.89     0.20  810.84    1.85
# 5        11961.41     0.17  682.99    2.12
# 6        11400.20     0.15  621.09    2.27

# %% [markdown]
# #### Analizar los gráficos

# %%
metricas.plot(subplots = True, figsize = (10,6), layout = (2,2), sharex = False);

# %% [markdown]
# ### Segmentación final con la mejor solucion

# %%
mejor_solucion = 3

#Instanciar
cluster = KMeans(n_clusters = mejor_solucion, n_init=10)
    
#Entrenar
cluster.fit(df)
# Out:
# KMeans(n_clusters=3, n_init=10)

# %% [markdown]
# ## EVALUAR

# %% [markdown]
# Comprobar que los perfiles obtenidos en entrenamiento son similares a los objetidos al predecir sobre validación.

# %% [markdown]
# ### Calcular el segmento en entrenamiento y en validación

# %%
df['segmento'] = cluster.predict(df)

# %% [markdown]
# ## PERFILAR LOS SEGMENTOS

# %%
df.groupby('segmento').mean().T \
    .style.highlight_max(color = 'lightgreen', axis = 1) \
    .highlight_min(color = 'red', axis = 1)
# Out:
# <style type="text/css">
# #T_5ee80_row0_col1, #T_5ee80_row1_col0, #T_5ee80_row2_col2, #T_5ee80_row3_col1, #T_5ee80_row4_col1, #T_5ee80_row5_col0, #T_5ee80_row6_col2, #T_5ee80_row7_col1, #T_5ee80_row8_col0, #T_5ee80_row9_col2, #T_5ee80_row10_col1, #T_5ee80_row11_col1, #T_5ee80_row12_col1, #T_5ee80_row13_col0, #T_5ee80_row14_col2, #T_5ee80_row15_col0, #T_5ee80_row16_col0, #T_5ee80_row17_col2, #T_5ee80_row18_col2, #T_5ee80_row19_col2, #T_5ee80_row20_col2, #T_5ee80_row21_col0, #T_5ee80_row22_col0, #T_5ee80_row23_col2, #T_5ee80_row24_col0, #T_5ee80_row25_col0, #T_5ee80_row26_col0, #T_5ee80_row27_col1, #T_5ee80_row28_col0, #T_5ee80_row29_col0, #T_5ee80_row30_col2, #T_5ee80_row31_col0, #T_5ee80_row32_col1, #T_5ee80_row33_col2, #T_5ee80_row34_col2, #T_5ee80_row35_col0, #T_5ee80_row36_col0, #T_5ee80_row37_col0, #T_5ee80_row38_col0, #T_5ee80_row39_col1, #T_5ee80_row40_col2, #T_5ee80_row41_col2 {
#   background-color: lightgreen;
# }
# #T_5ee80_row0_col2, #T_5ee80_row1_col1, #T_5ee80_row2_col0, #T_5ee80_row3_col0, #T_5ee80_row4_col2, #T_5ee80_row5_col1, #T_5ee80_row6_col0, #T_5ee80_row7_col0, #T_5ee80_row8_col2, #T_5ee80_row9_col0, #T_5ee80_row10_col0, #T_5ee80_row11_col2, #T_5ee80_row12_col2, #T_5ee80_row13_col1, #T_5ee80_row14_col0, #T_5ee80_row15_col1, #T_5ee80_row16_col1, #T_5ee80_row17_col1, #T_5ee80_row18_col1, #T_5ee80_row19_col1, #T_5ee80_row20_col1, #T_5ee80_row21_col1, #T_5ee80_row22_col1, #T_5ee80_row23_col1, #T_5ee80_row24_col1, #T_5ee80_row25_col1, #T_5ee80_row26_col1, #T_5ee80_row27_col0, #T_5ee80_row28_col1, #T_5ee80_row29_col1, #T_5ee80_row30_col0, #T_5ee80_row31_col2, #T_5ee80_row32_col2, #T_5ee80_row33_col1, #T_5ee80_row34_col0, #T_5ee80_row35_col2, #T_5ee80_row36_col1, #T_5ee80_row37_col1, #T_5ee80_row38_col1, #T_5ee80_row39_col2, #T_5ee80_row40_col1, #T_5ee80_row41_col0 {
#   background-color: red;
# }
# </style>
# <table id="T_5ee80">
#   <thead>
#     <tr>
#       <th class="index_name level0" >segmento</th>
#       <th id="T_5ee80_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_5ee80_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_5ee80_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ee80_level0_row0" class="row_heading level0 row0" >origen_API</th>
#       <td id="T_5ee80_row0_col0" class="data row0 col0" >0.029314</td>
#       <td id="T_5ee80_row0_col1" class="data row0 col1" >0.947131</td>
#       <td id="T_5ee80_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row1" class="row_heading level0 row1" >origen_Landing Page Submission</th>
#       <td id="T_5ee80_row1_col0" class="data row1 col0" >0.964049</td>
#       <td id="T_5ee80_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_5ee80_row1_col2" class="data row1 col2" >0.883752</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row2" class="row_heading level0 row2" >origen_Lead Add Form</th>
#       <td id="T_5ee80_row2_col0" class="data row2 col0" >0.006637</td>
#       <td id="T_5ee80_row2_col1" class="data row2 col1" >0.036750</td>
#       <td id="T_5ee80_row2_col2" class="data row2 col2" >0.110304</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row3" class="row_heading level0 row3" >origen_OTROS</th>
#       <td id="T_5ee80_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_5ee80_row3_col1" class="data row3 col1" >0.016119</td>
#       <td id="T_5ee80_row3_col2" class="data row3 col2" >0.005945</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row4" class="row_heading level0 row4" >fuente_Chat</th>
#       <td id="T_5ee80_row4_col0" class="data row4 col0" >0.016593</td>
#       <td id="T_5ee80_row4_col1" class="data row4 col1" >0.177950</td>
#       <td id="T_5ee80_row4_col2" class="data row4 col2" >0.000661</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row5" class="row_heading level0 row5" >fuente_Direct Traffic</th>
#       <td id="T_5ee80_row5_col0" class="data row5 col0" >0.674226</td>
#       <td id="T_5ee80_row5_col1" class="data row5 col1" >0.039974</td>
#       <td id="T_5ee80_row5_col2" class="data row5 col2" >0.188904</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row6" class="row_heading level0 row6" >fuente_Google</th>
#       <td id="T_5ee80_row6_col0" class="data row6 col0" >0.091814</td>
#       <td id="T_5ee80_row6_col1" class="data row6 col1" >0.488072</td>
#       <td id="T_5ee80_row6_col2" class="data row6 col2" >0.630779</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row7" class="row_heading level0 row7" >fuente_OTROS</th>
#       <td id="T_5ee80_row7_col0" class="data row7 col0" >0.007743</td>
#       <td id="T_5ee80_row7_col1" class="data row7 col1" >0.070922</td>
#       <td id="T_5ee80_row7_col2" class="data row7 col2" >0.015192</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row8" class="row_heading level0 row8" >fuente_Organic Search</th>
#       <td id="T_5ee80_row8_col0" class="data row8 col0" >0.202987</td>
#       <td id="T_5ee80_row8_col1" class="data row8 col1" >0.191489</td>
#       <td id="T_5ee80_row8_col2" class="data row8 col2" >0.058124</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row9" class="row_heading level0 row9" >fuente_Reference</th>
#       <td id="T_5ee80_row9_col0" class="data row9 col0" >0.006637</td>
#       <td id="T_5ee80_row9_col1" class="data row9 col1" >0.031593</td>
#       <td id="T_5ee80_row9_col2" class="data row9 col2" >0.106341</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row10" class="row_heading level0 row10" >ult_actividad_Chat Conversation</th>
#       <td id="T_5ee80_row10_col0" class="data row10 col0" >0.019358</td>
#       <td id="T_5ee80_row10_col1" class="data row10 col1" >0.135397</td>
#       <td id="T_5ee80_row10_col2" class="data row10 col2" >0.020476</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row11" class="row_heading level0 row11" >ult_actividad_Converted to Lead</th>
#       <td id="T_5ee80_row11_col0" class="data row11 col0" >0.063606</td>
#       <td id="T_5ee80_row11_col1" class="data row11 col1" >0.069632</td>
#       <td id="T_5ee80_row11_col2" class="data row11 col2" >0.052180</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row12" class="row_heading level0 row12" >ult_actividad_Email Link Clicked</th>
#       <td id="T_5ee80_row12_col0" class="data row12 col0" >0.027655</td>
#       <td id="T_5ee80_row12_col1" class="data row12 col1" >0.036106</td>
#       <td id="T_5ee80_row12_col2" class="data row12 col2" >0.027081</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row13" class="row_heading level0 row13" >ult_actividad_Email Opened</th>
#       <td id="T_5ee80_row13_col0" class="data row13 col0" >0.444690</td>
#       <td id="T_5ee80_row13_col1" class="data row13 col1" >0.371373</td>
#       <td id="T_5ee80_row13_col2" class="data row13 col2" >0.418758</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row14" class="row_heading level0 row14" >ult_actividad_OTROS</th>
#       <td id="T_5ee80_row14_col0" class="data row14 col0" >0.025996</td>
#       <td id="T_5ee80_row14_col1" class="data row14 col1" >0.053514</td>
#       <td id="T_5ee80_row14_col2" class="data row14 col2" >0.070674</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row15" class="row_heading level0 row15" >ult_actividad_Page Visited on Website</th>
#       <td id="T_5ee80_row15_col0" class="data row15 col0" >0.081305</td>
#       <td id="T_5ee80_row15_col1" class="data row15 col1" >0.074790</td>
#       <td id="T_5ee80_row15_col2" class="data row15 col2" >0.077939</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row16" class="row_heading level0 row16" >ult_actividad_SMS Sent</th>
#       <td id="T_5ee80_row16_col0" class="data row16 col0" >0.337389</td>
#       <td id="T_5ee80_row16_col1" class="data row16 col1" >0.259188</td>
#       <td id="T_5ee80_row16_col2" class="data row16 col2" >0.332893</td>
#     </tr>
#     <tr>
#       <th id="T_5ee80_level0_row17" class="row_heading level0 row17" >ambito_Banking, Investment And Insurance</th>
#       <td id="T_5ee80_row17_col0" class="data row17 col0" >0.05807

# %% [markdown]
# **ANÁLISIS CON 3 SEGMENTOS:**
#
# Vemos que en la variable compra prácticamente los 3 segmentos convierten igual. Esto ya nos indica a primeras que la segmentación elegida no es muy buena. Vamos a probar con 4.

# %%
mejor_solucion = 4

#Instanciar
cluster = KMeans(n_clusters = mejor_solucion, n_init=10)
#Entrenar
cluster.fit(df)

df['segmento'] = cluster.predict(df)

df.groupby('segmento').mean().T \
    .style.highlight_max(color = 'lightgreen', axis = 1) \
    .highlight_min(color = 'red', axis = 1)
# Out:
# <style type="text/css">
# #T_d7ae4_row0_col0, #T_d7ae4_row1_col2, #T_d7ae4_row2_col3, #T_d7ae4_row3_col0, #T_d7ae4_row4_col0, #T_d7ae4_row5_col1, #T_d7ae4_row6_col2, #T_d7ae4_row7_col0, #T_d7ae4_row8_col1, #T_d7ae4_row9_col3, #T_d7ae4_row10_col0, #T_d7ae4_row11_col0, #T_d7ae4_row12_col3, #T_d7ae4_row13_col1, #T_d7ae4_row14_col3, #T_d7ae4_row15_col2, #T_d7ae4_row16_col2, #T_d7ae4_row17_col3, #T_d7ae4_row18_col2, #T_d7ae4_row19_col2, #T_d7ae4_row20_col2, #T_d7ae4_row21_col1, #T_d7ae4_row22_col1, #T_d7ae4_row23_col3, #T_d7ae4_row24_col1, #T_d7ae4_row25_col1, #T_d7ae4_row26_col1, #T_d7ae4_row27_col0, #T_d7ae4_row28_col1, #T_d7ae4_row29_col1, #T_d7ae4_row30_col3, #T_d7ae4_row31_col1, #T_d7ae4_row32_col0, #T_d7ae4_row33_col3, #T_d7ae4_row34_col2, #T_d7ae4_row35_col1, #T_d7ae4_row36_col1, #T_d7ae4_row37_col2, #T_d7ae4_row38_col2, #T_d7ae4_row39_col3, #T_d7ae4_row40_col3, #T_d7ae4_row41_col3 {
#   background-color: lightgreen;
# }
# #T_d7ae4_row0_col2, #T_d7ae4_row0_col3, #T_d7ae4_row1_col0, #T_d7ae4_row1_col3, #T_d7ae4_row2_col2, #T_d7ae4_row3_col1, #T_d7ae4_row4_col2, #T_d7ae4_row5_col3, #T_d7ae4_row6_col3, #T_d7ae4_row7_col1, #T_d7ae4_row8_col3, #T_d7ae4_row9_col0, #T_d7ae4_row9_col2, #T_d7ae4_row10_col3, #T_d7ae4_row11_col3, #T_d7ae4_row12_col2, #T_d7ae4_row13_col3, #T_d7ae4_row14_col1, #T_d7ae4_row15_col3, #T_d7ae4_row16_col0, #T_d7ae4_row17_col0, #T_d7ae4_row18_col0, #T_d7ae4_row19_col0, #T_d7ae4_row20_col0, #T_d7ae4_row21_col0, #T_d7ae4_row22_col0, #T_d7ae4_row23_col0, #T_d7ae4_row24_col3, #T_d7ae4_row25_col0, #T_d7ae4_row26_col0, #T_d7ae4_row27_col1, #T_d7ae4_row28_col0, #T_d7ae4_row29_col3, #T_d7ae4_row30_col1, #T_d7ae4_row31_col2, #T_d7ae4_row32_col3, #T_d7ae4_row33_col0, #T_d7ae4_row34_col1, #T_d7ae4_row35_col2, #T_d7ae4_row36_col3, #T_d7ae4_row37_col3, #T_d7ae4_row38_col3, #T_d7ae4_row39_col2, #T_d7ae4_row40_col0, #T_d7ae4_row41_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_d7ae4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >segmento</th>
#       <th id="T_d7ae4_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d7ae4_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d7ae4_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_d7ae4_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7ae4_level0_row0" class="row_heading level0 row0" >origen_API</th>
#       <td id="T_d7ae4_row0_col0" class="data row0 col0" >0.981952</td>
#       <td id="T_d7ae4_row0_col1" class="data row0 col1" >0.029330</td>
#       <td id="T_d7ae4_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_d7ae4_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row1" class="row_heading level0 row1" >origen_Landing Page Submission</th>
#       <td id="T_d7ae4_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_d7ae4_row1_col1" class="data row1 col1" >0.964582</td>
#       <td id="T_d7ae4_row1_col2" class="data row1 col2" >0.994796</td>
#       <td id="T_d7ae4_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row2" class="row_heading level0 row2" >origen_Lead Add Form</th>
#       <td id="T_d7ae4_row2_col0" class="data row2 col0" >0.001337</td>
#       <td id="T_d7ae4_row2_col1" class="data row2 col1" >0.006087</td>
#       <td id="T_d7ae4_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_d7ae4_row2_col3" class="data row2 col3" >0.991111</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row3" class="row_heading level0 row3" >origen_OTROS</th>
#       <td id="T_d7ae4_row3_col0" class="data row3 col0" >0.016711</td>
#       <td id="T_d7ae4_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_d7ae4_row3_col2" class="data row3 col2" >0.005204</td>
#       <td id="T_d7ae4_row3_col3" class="data row3 col3" >0.008889</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row4" class="row_heading level0 row4" >fuente_Chat</th>
#       <td id="T_d7ae4_row4_col0" class="data row4 col0" >0.184492</td>
#       <td id="T_d7ae4_row4_col1" class="data row4 col1" >0.016602</td>
#       <td id="T_d7ae4_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_d7ae4_row4_col3" class="data row4 col3" >0.004444</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row5" class="row_heading level0 row5" >fuente_Direct Traffic</th>
#       <td id="T_d7ae4_row5_col0" class="data row5 col0" >0.041444</td>
#       <td id="T_d7ae4_row5_col1" class="data row5 col1" >0.674599</td>
#       <td id="T_d7ae4_row5_col2" class="data row5 col2" >0.212639</td>
#       <td id="T_d7ae4_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row6" class="row_heading level0 row6" >fuente_Google</th>
#       <td id="T_d7ae4_row6_col0" class="data row6 col0" >0.506016</td>
#       <td id="T_d7ae4_row6_col1" class="data row6 col1" >0.091865</td>
#       <td id="T_d7ae4_row6_col2" class="data row6 col2" >0.709294</td>
#       <td id="T_d7ae4_row6_col3" class="data row6 col3" >0.004444</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row7" class="row_heading level0 row7" >fuente_OTROS</th>
#       <td id="T_d7ae4_row7_col0" class="data row7 col0" >0.069519</td>
#       <td id="T_d7ae4_row7_col1" class="data row7 col1" >0.007748</td>
#       <td id="T_d7ae4_row7_col2" class="data row7 col2" >0.012639</td>
#       <td id="T_d7ae4_row7_col3" class="data row7 col3" >0.053333</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row8" class="row_heading level0 row8" >fuente_Organic Search</th>
#       <td id="T_d7ae4_row8_col0" class="data row8 col0" >0.198529</td>
#       <td id="T_d7ae4_row8_col1" class="data row8 col1" >0.203099</td>
#       <td id="T_d7ae4_row8_col2" class="data row8 col2" >0.065428</td>
#       <td id="T_d7ae4_row8_col3" class="data row8 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row9" class="row_heading level0 row9" >fuente_Reference</th>
#       <td id="T_d7ae4_row9_col0" class="data row9 col0" >0.000000</td>
#       <td id="T_d7ae4_row9_col1" class="data row9 col1" >0.006087</td>
#       <td id="T_d7ae4_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_d7ae4_row9_col3" class="data row9 col3" >0.937778</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row10" class="row_heading level0 row10" >ult_actividad_Chat Conversation</th>
#       <td id="T_d7ae4_row10_col0" class="data row10 col0" >0.140374</td>
#       <td id="T_d7ae4_row10_col1" class="data row10 col1" >0.019369</td>
#       <td id="T_d7ae4_row10_col2" class="data row10 col2" >0.022305</td>
#       <td id="T_d7ae4_row10_col3" class="data row10 col3" >0.004444</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row11" class="row_heading level0 row11" >ult_actividad_Converted to Lead</th>
#       <td id="T_d7ae4_row11_col0" class="data row11 col0" >0.072193</td>
#       <td id="T_d7ae4_row11_col1" class="data row11 col1" >0.063641</td>
#       <td id="T_d7ae4_row11_col2" class="data row11 col2" >0.058736</td>
#       <td id="T_d7ae4_row11_col3" class="data row11 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row12" class="row_heading level0 row12" >ult_actividad_Email Link Clicked</th>
#       <td id="T_d7ae4_row12_col0" class="data row12 col0" >0.036096</td>
#       <td id="T_d7ae4_row12_col1" class="data row12 col1" >0.027670</td>
#       <td id="T_d7ae4_row12_col2" class="data row12 col2" >0.020818</td>
#       <td id="T_d7ae4_row12_col3" class="data row12 col3" >0.066667</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row13" class="row_heading level0 row13" >ult_actividad_Email Opened</th>
#       <td id="T_d7ae4_row13_col0" class="data row13 col0" >0.376337</td>
#       <td id="T_d7ae4_row13_col1" class="data row13 col1" >0.444936</td>
#       <td id="T_d7ae4_row13_col2" class="data row13 col2" >0.427509</td>
#       <td id="T_d7ae4_row13_col3" class="data row13 col3" >0.320000</td>
#     </tr>
#     <tr>
#       <th id="T_d7ae4_level0_row14" class="row_heading level0 row

# %% [markdown]
# **ANÁLISIS CON 4 SEGMENTOS:**
#
# La variable compra mejora con un grupo que convierte mucho, pero los otros 3 son prácticamente iguales. Vamos a probar eliminando algunas variables del análisis. Las menos relevantes podrían ser el *origen* y la *fuente*.

# %%
df = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_df)
df.drop(columns = ['origen_API','origen_Landing Page Submission','origen_Lead Add Form','origen_OTROS',
                   'fuente_Chat','fuente_Direct Traffic','fuente_Google','fuente_OTROS','fuente_Organic Search','fuente_Reference'],
                    inplace = True)

# %%
min_k = 3
max_k = 7
soluciones = list(range(min_k,max_k))

codo = []
silueta = []
calins = []
davies = []

for solucion in soluciones:
    
    #Instanciar
    cluster = KMeans(n_clusters = solucion, n_init=10)
    
    #Entrenar
    cluster.fit(df)
    
    #Recoger las métricas
    codo.append(cluster.inertia_)
    silueta.append(silhouette_score(df, cluster.labels_))
    calins.append(calinski_harabasz_score(df, cluster.labels_))
    davies.append(davies_bouldin_score(df, cluster.labels_))

metricas = pd.DataFrame({'Solucion':soluciones,'Codo': codo,'Silueta':silueta,'Calins':calins,'Davies':davies}).set_index('Solucion')
metricas.plot(subplots = True, figsize = (10,6), layout = (2,2), sharex = False);

# %%
mejor_solucion = 6

#Instanciar
cluster = KMeans(n_clusters = mejor_solucion, n_init=10)
#Entrenar
cluster.fit(df)

df['segmento'] = cluster.predict(df)

df.groupby('segmento').mean().T \
    .style.highlight_max(color = 'lightgreen', axis = 1) \
    .highlight_min(color = 'red', axis = 1)
# Out:
# <style type="text/css">
# #T_96194_row0_col3, #T_96194_row0_col5, #T_96194_row1_col3, #T_96194_row1_col5, #T_96194_row2_col3, #T_96194_row2_col5, #T_96194_row3_col0, #T_96194_row3_col5, #T_96194_row4_col3, #T_96194_row4_col5, #T_96194_row5_col3, #T_96194_row5_col5, #T_96194_row6_col1, #T_96194_row6_col3, #T_96194_row6_col4, #T_96194_row7_col4, #T_96194_row8_col4, #T_96194_row9_col4, #T_96194_row10_col4, #T_96194_row11_col4, #T_96194_row12_col4, #T_96194_row13_col4, #T_96194_row14_col4, #T_96194_row15_col4, #T_96194_row16_col4, #T_96194_row17_col0, #T_96194_row17_col1, #T_96194_row18_col4, #T_96194_row19_col4, #T_96194_row20_col0, #T_96194_row21_col2, #T_96194_row22_col2, #T_96194_row23_col0, #T_96194_row23_col1, #T_96194_row23_col5, #T_96194_row24_col0, #T_96194_row24_col3, #T_96194_row25_col1, #T_96194_row25_col4, #T_96194_row25_col5, #T_96194_row26_col4, #T_96194_row27_col4, #T_96194_row28_col4, #T_96194_row29_col3, #T_96194_row30_col4, #T_96194_row31_col4 {
#   background-color: red;
# }
# #T_96194_row0_col4, #T_96194_row1_col4, #T_96194_row2_col0, #T_96194_row3_col3, #T_96194_row4_col2, #T_96194_row5_col0, #T_96194_row6_col5, #T_96194_row7_col0, #T_96194_row8_col0, #T_96194_row9_col1, #T_96194_row10_col1, #T_96194_row11_col3, #T_96194_row12_col3, #T_96194_row13_col1, #T_96194_row14_col0, #T_96194_row15_col2, #T_96194_row16_col2, #T_96194_row17_col4, #T_96194_row18_col3, #T_96194_row19_col0, #T_96194_row20_col1, #T_96194_row21_col3, #T_96194_row22_col5, #T_96194_row23_col2, #T_96194_row24_col1, #T_96194_row24_col4, #T_96194_row24_col5, #T_96194_row25_col0, #T_96194_row25_col3, #T_96194_row26_col0, #T_96194_row27_col2, #T_96194_row28_col0, #T_96194_row29_col2, #T_96194_row30_col2, #T_96194_row31_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_96194">
#   <thead>
#     <tr>
#       <th class="index_name level0" >segmento</th>
#       <th id="T_96194_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_96194_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_96194_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_96194_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_96194_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_96194_level0_col5" class="col_heading level0 col5" >5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96194_level0_row0" class="row_heading level0 row0" >ult_actividad_Chat Conversation</th>
#       <td id="T_96194_row0_col0" class="data row0 col0" >0.041711</td>
#       <td id="T_96194_row0_col1" class="data row0 col1" >0.050380</td>
#       <td id="T_96194_row0_col2" class="data row0 col2" >0.021739</td>
#       <td id="T_96194_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_96194_row0_col4" class="data row0 col4" >0.192308</td>
#       <td id="T_96194_row0_col5" class="data row0 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_96194_level0_row1" class="row_heading level0 row1" >ult_actividad_Converted to Lead</th>
#       <td id="T_96194_row1_col0" class="data row1 col0" >0.115508</td>
#       <td id="T_96194_row1_col1" class="data row1 col1" >0.067490</td>
#       <td id="T_96194_row1_col2" class="data row1 col2" >0.033816</td>
#       <td id="T_96194_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_96194_row1_col4" class="data row1 col4" >0.119780</td>
#       <td id="T_96194_row1_col5" class="data row1 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_96194_level0_row2" class="row_heading level0 row2" >ult_actividad_Email Link Clicked</th>
#       <td id="T_96194_row2_col0" class="data row2 col0" >0.051337</td>
#       <td id="T_96194_row2_col1" class="data row2 col1" >0.038973</td>
#       <td id="T_96194_row2_col2" class="data row2 col2" >0.028986</td>
#       <td id="T_96194_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_96194_row2_col4" class="data row2 col4" >0.050549</td>
#       <td id="T_96194_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_96194_level0_row3" class="row_heading level0 row3" >ult_actividad_Email Opened</th>
#       <td id="T_96194_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_96194_row3_col1" class="data row3 col1" >0.647338</td>
#       <td id="T_96194_row3_col2" class="data row3 col2" >0.338164</td>
#       <td id="T_96194_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_96194_row3_col4" class="data row3 col4" >0.463736</td>
#       <td id="T_96194_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_96194_level0_row4" class="row_heading level0 row4" >ult_actividad_OTROS</th>
#       <td id="T_96194_row4_col0" class="data row4 col0" >0.049198</td>
#       <td id="T_96194_row4_col1" class="data row4 col1" >0.087452</td>
#       <td id="T_96194_row4_col2" class="data row4 col2" >0.096618</td>
#       <td id="T_96194_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_96194_row4_col4" class="data row4 col4" >0.064835</td>
#       <td id="T_96194_row4_col5" class="data row4 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_96194_level0_row5" class="row_heading level0 row5" >ult_actividad_Page Visited on Website</th>
#       <td id="T_96194_row5_col0" class="data row5 col0" >0.154011</td>
#       <td id="T_96194_row5_col1" class="data row5 col1" >0.108365</td>
#       <td id="T_96194_row5_col2" class="data row5 col2" >0.057971</td>
#       <td id="T_96194_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_96194_row5_col4" class="data row5 col4" >0.108791</td>
#       <td id="T_96194_row5_col5" class="data row5 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_96194_level0_row6" class="row_heading level0 row6" >ult_actividad_SMS Sent</th>
#       <td id="T_96194_row6_col0" class="data row6 col0" >0.588235</td>
#       <td id="T_96194_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_96194_row6_col2" class="data row6 col2" >0.422705</td>
#       <td id="T_96194_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_96194_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_96194_row6_col5" class="data row6 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_96194_level0_row7" class="row_heading level0 row7" >ambito_Banking, Investment And Insurance</th>
#       <td id="T_96194_row7_col0" class="data row7 col0" >0.065241</td>
#       <td id="T_96194_row7_col1" class="data row7 col1" >0.063688</td>
#       <td id="T_96194_row7_col2" class="data row7 col2" >0.048309</td>
#       <td id="T_96194_row7_col3" class="data row7 col3" >0.050584</td>
#       <td id="T_96194_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_96194_row7_col5" class="data row7 col5" >0.050569</td>
#     </tr>
#     <tr>
#       <th id="T_96194_level0_row8" class="row_heading level0 row8" >ambito_Business Administration</th>
#       <td id="T_96194_row8_col0" class="data row8 col0" >0.070588</td>
#       <td id="T_96194_row8_col1" class="data row8 col1" >0.067490</td>
#       <td id="T_96194_row8_col2" class="data row8 col2" >0.065217</td>
#       <td id="T_96194_row8_col3" class="data row8 col3" >0.068742</td>
#       <td id="T_96194_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_96194_row8_col5" class="data row8 col5" >0.046776</td>
#     </tr>
#     <tr>
#       <th id="T_96194_level0_row9" class="row_heading level0 row9" >ambito_Finance Management</th>
#       <td id="T_96194_row9_col0" class="data row9 col0" >0.144385</td>
#       <td id="T_96194_row9_col1" class="data row9 col1" >0.185361</td>
#       <td id="T_96194_row9_col2" class="data row9 col2" >0.157005</td>
#       <td id="T_96194_row9_col3" class="data row9 col3" >0.156939</td>
#       <td id="T_96194_row9_col4" class="data row9 col4" >0.000000</td>
#       <td id="T_96194_row9_col5" class="data row9 col5" >0.117573</td>
#     </tr>
#     <tr>
#       <th id="T_96194_level0_row10" class="row_heading level0 row10" >ambito_Human Resource Management</th>
#       <td id="T_96194_row10_col0" class="data row10 col0" >

# %% [markdown]
# **ANÁLISIS CON 6 SEGMENTOS SIN ORIGEN NI FUENTE:**
#
# La variable compra ahora se diferencia mejor, pero siguen sin verse divisiones claras en el resto de métricas. Así repitiendo este proceso de sacar y meter variables y probar diferentes segmentaciones vamos optimizando poco a poco la solución y el algoritmo. En este caso la mejor solución que se ha encontrado es la siguiente.

# %%
df = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_df)
df.drop(columns = ['fuente_Chat',
                   'fuente_Direct Traffic',
                   'fuente_Google',
                   'fuente_OTROS',
                   'fuente_Organic Search',
                   'fuente_Reference',
                   'ambito_Banking, Investment And Insurance',
                   'ambito_Business Administration',
                   'ambito_Finance Management',
                   'ambito_Human Resource Management',
                   'ambito_IT Projects Management',
                   'ambito_International Business',
                   'ambito_Select',
                   'ambito_Supply Chain Management',
                   'ambito_Select',
                   'ambito_Supply Chain Management',
                   'ambito_Travel and Tourism',
                   'ambito_Marketing Management',
                   'ambito_Media and Advertising',
                   'ambito_OTROS',
                   'ambito_Operations Management',
                   'descarga_lm_No',
                   'descarga_lm_Yes',
                   'visitas_total_mms',
                   'paginas_vistas_visita_mms'],
                    inplace = True)

# %%
min_k = 3
max_k = 7
soluciones = list(range(min_k,max_k))

codo = []
silueta = []
calins = []
davies = []

for solucion in soluciones:
    
    #Instanciar
    cluster = KMeans(n_clusters = solucion, n_init=10)
    
    #Entrenar
    cluster.fit(df)
    
    #Recoger las métricas
    codo.append(cluster.inertia_)
    silueta.append(silhouette_score(df, cluster.labels_))
    calins.append(calinski_harabasz_score(df, cluster.labels_))
    davies.append(davies_bouldin_score(df, cluster.labels_))

metricas = pd.DataFrame({'Solucion':soluciones,'Codo': codo,'Silueta':silueta,'Calins':calins,'Davies':davies}).set_index('Solucion')
metricas.plot(subplots = True, figsize = (10,6), layout = (2,2), sharex = False);

# %%
mejor_solucion = 4

#Instanciar
cluster = KMeans(n_clusters = mejor_solucion, n_init=10)
#Entrenar
cluster.fit(df)

df['segmento'] = cluster.predict(df)

df.groupby('segmento').mean().T \
    .style.highlight_max(color = 'lightgreen', axis = 1) \
    .highlight_min(color = 'red', axis = 1)
# Out:
# <style type="text/css">
# #T_8129d_row0_col1, #T_8129d_row0_col2, #T_8129d_row1_col3, #T_8129d_row2_col2, #T_8129d_row3_col2, #T_8129d_row4_col2, #T_8129d_row5_col2, #T_8129d_row6_col2, #T_8129d_row7_col1, #T_8129d_row8_col2, #T_8129d_row9_col2, #T_8129d_row10_col2, #T_8129d_row11_col1, #T_8129d_row12_col1, #T_8129d_row13_col0, #T_8129d_row14_col1, #T_8129d_row15_col3, #T_8129d_row16_col2, #T_8129d_row17_col3, #T_8129d_row18_col2 {
#   background-color: red;
# }
# #T_8129d_row0_col3, #T_8129d_row1_col2, #T_8129d_row2_col0, #T_8129d_row3_col3, #T_8129d_row4_col3, #T_8129d_row5_col1, #T_8129d_row6_col1, #T_8129d_row7_col2, #T_8129d_row8_col0, #T_8129d_row9_col1, #T_8129d_row10_col1, #T_8129d_row11_col0, #T_8129d_row12_col2, #T_8129d_row13_col1, #T_8129d_row14_col0, #T_8129d_row15_col0, #T_8129d_row16_col0, #T_8129d_row17_col0, #T_8129d_row18_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8129d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >segmento</th>
#       <th id="T_8129d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_8129d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_8129d_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_8129d_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8129d_level0_row0" class="row_heading level0 row0" >origen_API</th>
#       <td id="T_8129d_row0_col0" class="data row0 col0" >0.232274</td>
#       <td id="T_8129d_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_8129d_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_8129d_row0_col3" class="data row0 col3" >0.915330</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row1" class="row_heading level0 row1" >origen_Landing Page Submission</th>
#       <td id="T_8129d_row1_col0" class="data row1 col0" >0.542787</td>
#       <td id="T_8129d_row1_col1" class="data row1 col1" >0.971865</td>
#       <td id="T_8129d_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_8129d_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row2" class="row_heading level0 row2" >origen_Lead Add Form</th>
#       <td id="T_8129d_row2_col0" class="data row2 col0" >0.220049</td>
#       <td id="T_8129d_row2_col1" class="data row2 col1" >0.022630</td>
#       <td id="T_8129d_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_8129d_row2_col3" class="data row2 col3" >0.069917</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row3" class="row_heading level0 row3" >origen_OTROS</th>
#       <td id="T_8129d_row3_col0" class="data row3 col0" >0.004890</td>
#       <td id="T_8129d_row3_col1" class="data row3 col1" >0.005505</td>
#       <td id="T_8129d_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_8129d_row3_col3" class="data row3 col3" >0.014753</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row4" class="row_heading level0 row4" >ult_actividad_Chat Conversation</th>
#       <td id="T_8129d_row4_col0" class="data row4 col0" >0.017115</td>
#       <td id="T_8129d_row4_col1" class="data row4 col1" >0.036086</td>
#       <td id="T_8129d_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_8129d_row4_col3" class="data row4 col3" >0.134702</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row5" class="row_heading level0 row5" >ult_actividad_Converted to Lead</th>
#       <td id="T_8129d_row5_col0" class="data row5 col0" >0.031785</td>
#       <td id="T_8129d_row5_col1" class="data row5 col1" >0.111927</td>
#       <td id="T_8129d_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_8129d_row5_col3" class="data row5 col3" >0.067992</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row6" class="row_heading level0 row6" >ult_actividad_Email Link Clicked</th>
#       <td id="T_8129d_row6_col0" class="data row6 col0" >0.031785</td>
#       <td id="T_8129d_row6_col1" class="data row6 col1" >0.044648</td>
#       <td id="T_8129d_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_8129d_row6_col3" class="data row6 col3" >0.039128</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row7" class="row_heading level0 row7" >ult_actividad_Email Opened</th>
#       <td id="T_8129d_row7_col0" class="data row7 col0" >0.332518</td>
#       <td id="T_8129d_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_8129d_row7_col2" class="data row7 col2" >1.000000</td>
#       <td id="T_8129d_row7_col3" class="data row7 col3" >0.389994</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row8" class="row_heading level0 row8" >ult_actividad_OTROS</th>
#       <td id="T_8129d_row8_col0" class="data row8 col0" >0.100244</td>
#       <td id="T_8129d_row8_col1" class="data row8 col1" >0.057492</td>
#       <td id="T_8129d_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_8129d_row8_col3" class="data row8 col3" >0.065427</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row9" class="row_heading level0 row9" >ult_actividad_Page Visited on Website</th>
#       <td id="T_8129d_row9_col0" class="data row9 col0" >0.056235</td>
#       <td id="T_8129d_row9_col1" class="data row9 col1" >0.145566</td>
#       <td id="T_8129d_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_8129d_row9_col3" class="data row9 col3" >0.076972</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row10" class="row_heading level0 row10" >ult_actividad_SMS Sent</th>
#       <td id="T_8129d_row10_col0" class="data row10 col0" >0.430318</td>
#       <td id="T_8129d_row10_col1" class="data row10 col1" >0.604281</td>
#       <td id="T_8129d_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_8129d_row10_col3" class="data row10 col3" >0.225786</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row11" class="row_heading level0 row11" >ocupacion_OTROS</th>
#       <td id="T_8129d_row11_col0" class="data row11 col0" >0.012225</td>
#       <td id="T_8129d_row11_col1" class="data row11 col1" >0.001223</td>
#       <td id="T_8129d_row11_col2" class="data row11 col2" >0.005512</td>
#       <td id="T_8129d_row11_col3" class="data row11 col3" >0.005773</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row12" class="row_heading level0 row12" >ocupacion_Student</th>
#       <td id="T_8129d_row12_col0" class="data row12 col0" >0.019560</td>
#       <td id="T_8129d_row12_col1" class="data row12 col1" >0.017125</td>
#       <td id="T_8129d_row12_col2" class="data row12 col2" >0.025984</td>
#       <td id="T_8129d_row12_col3" class="data row12 col3" >0.019885</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row13" class="row_heading level0 row13" >ocupacion_Unemployed</th>
#       <td id="T_8129d_row13_col0" class="data row13 col0" >0.000000</td>
#       <td id="T_8129d_row13_col1" class="data row13 col1" >0.981651</td>
#       <td id="T_8129d_row13_col2" class="data row13 col2" >0.956693</td>
#       <td id="T_8129d_row13_col3" class="data row13 col3" >0.967928</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row14" class="row_heading level0 row14" >ocupacion_Working Professional</th>
#       <td id="T_8129d_row14_col0" class="data row14 col0" >0.968215</td>
#       <td id="T_8129d_row14_col1" class="data row14 col1" >0.000000</td>
#       <td id="T_8129d_row14_col2" class="data row14 col2" >0.011811</td>
#       <td id="T_8129d_row14_col3" class="data row14 col3" >0.006414</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row15" class="row_heading level0 row15" >tiempo_en_site_total_mms</th>
#       <td id="T_8129d_row15_col0" class="data row15 col0" >0.338904</td>
#       <td id="T_8129d_row15_col1" class="data row15 col1" >0.280867</td>
#       <td id="T_8129d_row15_col2" class="data row15 col2" >0.257079</td>
#       <td id="T_8129d_row15_col3" class="data row15 col3" >0.237069</td>
#     </tr>
#     <tr>
#       <th id="T_8129d_level0_row16" class="row_heading level0 row16" >score_actividad_mms</th>
#       <td id="T_8129d_row16_col0" class="data row16 col0" >0.665259</td>
#       <td id="T_8129d_row16_col1" class

# %% [markdown]
# Con esta segmentación y selección de variables vemos 4 grupos:
# * **Grupo que compra mucho:** Este perfil viene de rellenar el Lead add form y responden positivamente a los correos que se les envían. Los SMS no funcionan en este grupo y esta constituido mayormente por gente empleada. También permanecen mayor tiempo en la página web y realizan un mayor número de visitas.
# * **Grupo que no compra nada:** Este perfil viene mayormente de la Landing Page Submission. Los emails no funcionan en este grupo pese a ser bien recibidos. La mayor parte de este perfil son personas desempleadas, que no dedican mucho tiempo a visitar la página web.
# * **Grupos intermedio alto:** Este perfil también viene de la Landing Page Submission al igual que el que no compra, sin embargo el SMS funciona perfectamente para ellos. Hacen compras moderadas.
# * **Grupo intermedio bajo:** Este perfil viene exclusivamente del servidor API y responden bien a la actividad a través del chat. Son mayormente desempleados y no hacen muchas visitas.
#
# Resumiendo encontramos 4 grupos:
# * Perfil bueno - Trabajadores captados por email y que pasan tiempo visitando la página web.
# * Perfil intermedio alto - Mezcla de empleados y desempleados (mayormente desempleados) que vienen de la Landing Page Submission. Responden al SMS.
# * Perfil intermedio bajo - Desempleados que vienen de la API, no tienen mucha actividad en la web pero el chat funciona para ellos.
# * Perfil malo - Desempleados que vienen de la Landing Page Submission. No responden al SMS y pasan muy poco tiempo en la web.

# %%
df.segmento.value_counts(normalize = True)
# Out:
# segmento
# 0   0.35
# 1   0.29
# 3   0.27
# 2   0.09
# Name: proportion, dtype: float64

# %% [markdown]
# * El 16% de los leads son de muy alta calidad.
# * Al 30% hay que dejar de enviarles publicidad pues no responden de ninguna manera.
# * Hay un 54% de leads de calidad media con los que se puede seguir trabajando.

# %%
f, ax = plt.subplots()
y = 
ax.pie(x = df.segmento.value_counts(normalize = True), labels = ['1','2','3','4'], autopct = '%1.1f%%');
