# %% [markdown]
# # MODELIZACIÓN PARA NO SUPERVISADO

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

from sklearn.model_selection import GridSearchCV

#Autocompletar rápido
# %config IPCompleter.greedy=True

#Desactivar la notación científica
pd.options.display.float_format = '{:.2f}'.format

#Desactivar los warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/pelop/OneDrive/Desktop/Curso Data Science Pedro/2 CURSO DATA SCIENCE/03_MACHINE_LEARNING/07_CASOS/01_LEADSCORING'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_x = 'x_final.pickle'
nombre_y = 'y_final.pickle'

# %% [markdown]
# Cargar los datos.

# %%
x = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_x)
y = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_y)

# %% [markdown]
# ## MODELIZAR

# %% [markdown]
# ### Reservar el dataset de validacion

# %%
train_x,val_x,train_y,val_y = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Crear el espacio de soluciones

# %%
min_k = 5
max_k = 10

soluciones = list(range(min_k,max_k))

# %% [markdown]
# ### Crear listas para guardar la salida de cada métrica

# %%
codo = []
silueta = []
calins = []
davies = []

# %% [markdown]
# ### Analizar el espacio de soluciones

# %%
for solucion in soluciones:
    
    #Instanciar
    cluster = KMeans(n_clusters = solucion, n_init=10)
    
    #Entrenar
    cluster.fit(train_x)
    
    #Recoger las métricas
    codo.append(cluster.inertia_)
    silueta.append(silhouette_score(train_x, cluster.labels_))
    calins.append(calinski_harabasz_score(train_x, cluster.labels_))
    davies.append(davies_bouldin_score(train_x, cluster.labels_))

# %% [markdown]
# ### Identificar la mejor solucion

# %% [markdown]
# #### Analizar las métricas

# %%
metricas = pd.DataFrame({'Solucion':soluciones,
              'Codo': codo,
              'Silueta':silueta,
              'Calins':calins,           
              'Davies':davies}).set_index('Solucion')

metricas
# Out:
#              Codo  Silueta   Calins  Davies
# Solucion
# 5        10923.52     0.73 34846.35    0.44
# 6         7136.47     0.74 44093.28    0.35
# 7         5144.58     0.67 51834.48    0.41
# 8         3708.20     0.69 62378.30    0.37
# 9         2748.67     0.70 74215.22    0.33

# %% [markdown]
# #### Analizar los gráficos

# %%
metricas.plot(subplots = True, figsize = (12,8), layout = (2,2), sharex = False);

# %% [markdown]
# ### Segmentación final con la mejor solucion

# %%
mejor_solucion = 7

#Instanciar
cluster = KMeans(n_clusters = mejor_solucion, n_init=10)
    
#Entrenar
cluster.fit(train_x)
# Out:
# KMeans(n_clusters=7)

# %% [markdown]
# ## EVALUAR

# %% [markdown]
# Comprobar que los perfiles obtenidos en entrenamiento son similares a los objetidos al predecir sobre validación.

# %% [markdown]
# ### Calcular el segmento en entrenamiento y en validación

# %%
train_x['segmento'] = cluster.predict(train_x)

# %%
val_x['segmento'] = cluster.predict(val_x)

# %% [markdown]
# ### Comparar los perfiles

# %% [markdown]
# #### Calcular los perfiles

# %%
perfiles_train = train_x.groupby('segmento').mean().T.stack().reset_index()
perfiles_train.columns = ['variable','segmento','media']

perfiles_val = val_x.groupby('segmento').mean().T.stack().reset_index()
perfiles_val.columns = ['variable','segmento','media']

# %% [markdown]
# #### Comparar los perfiles

# %%
sns.set_style("whitegrid")

f, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (16,6))

sns.lineplot(ax = ax[0], data = perfiles_train, x = 'variable', y = 'media', hue = 'segmento')
ax[0].get_legend().remove()
ax[0].axes.xaxis.set_visible(False)

sns.lineplot(ax = ax[1], data = perfiles_val, x = 'variable', y = 'media', hue = 'segmento')
ax[1].get_legend().remove()
ax[1].axes.xaxis.set_visible(False)

# %% [markdown]
# ## PERFILAR LOS SEGMENTOS

# %%
train_x.groupby('segmento').mean().T \
    .style.highlight_max(color = 'lightgreen', axis = 1) \
    .highlight_min(color = 'red', axis = 1)
# Out:
# <style type="text/css">
# #T_88ebd_row0_col5, #T_88ebd_row1_col5, #T_88ebd_row2_col5, #T_88ebd_row3_col5, #T_88ebd_row4_col5, #T_88ebd_row5_col5, #T_88ebd_row6_col1, #T_88ebd_row6_col2, #T_88ebd_row6_col3, #T_88ebd_row6_col4, #T_88ebd_row7_col2, #T_88ebd_row8_col0, #T_88ebd_row8_col1, #T_88ebd_row8_col5, #T_88ebd_row8_col6, #T_88ebd_row9_col2, #T_88ebd_row10_col2, #T_88ebd_row11_col1, #T_88ebd_row11_col2, #T_88ebd_row11_col3, #T_88ebd_row11_col4, #T_88ebd_row12_col0, #T_88ebd_row12_col1, #T_88ebd_row12_col5, #T_88ebd_row12_col6, #T_88ebd_row13_col2, #T_88ebd_row14_col1, #T_88ebd_row14_col2, #T_88ebd_row14_col3, #T_88ebd_row14_col4, #T_88ebd_row15_col0, #T_88ebd_row15_col1, #T_88ebd_row15_col5, #T_88ebd_row15_col6, #T_88ebd_row16_col0, #T_88ebd_row16_col1, #T_88ebd_row16_col5, #T_88ebd_row16_col6, #T_88ebd_row17_col1, #T_88ebd_row17_col2, #T_88ebd_row17_col3, #T_88ebd_row17_col4 {
#   background-color: red;
# }
# #T_88ebd_row0_col6, #T_88ebd_row1_col6, #T_88ebd_row2_col6, #T_88ebd_row3_col6, #T_88ebd_row4_col6, #T_88ebd_row5_col6, #T_88ebd_row6_col0, #T_88ebd_row6_col5, #T_88ebd_row7_col0, #T_88ebd_row7_col1, #T_88ebd_row7_col3, #T_88ebd_row7_col4, #T_88ebd_row7_col5, #T_88ebd_row7_col6, #T_88ebd_row8_col2, #T_88ebd_row9_col0, #T_88ebd_row9_col1, #T_88ebd_row9_col3, #T_88ebd_row9_col4, #T_88ebd_row9_col5, #T_88ebd_row9_col6, #T_88ebd_row10_col0, #T_88ebd_row10_col1, #T_88ebd_row10_col3, #T_88ebd_row10_col4, #T_88ebd_row10_col5, #T_88ebd_row10_col6, #T_88ebd_row11_col0, #T_88ebd_row11_col5, #T_88ebd_row12_col2, #T_88ebd_row13_col0, #T_88ebd_row13_col1, #T_88ebd_row13_col3, #T_88ebd_row13_col4, #T_88ebd_row13_col5, #T_88ebd_row13_col6, #T_88ebd_row14_col0, #T_88ebd_row14_col5, #T_88ebd_row15_col2, #T_88ebd_row16_col2, #T_88ebd_row17_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_88ebd_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >segmento</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88ebd_level0_row0" class="row_heading level0 row0" >euribor3m_qt_mms</th>
#       <td id="T_88ebd_row0_col0" class="data row0 col0" >0.540127</td>
#       <td id="T_88ebd_row0_col1" class="data row0 col1" >0.415957</td>
#       <td id="T_88ebd_row0_col2" class="data row0 col2" >0.396024</td>
#       <td id="T_88ebd_row0_col3" class="data row0 col3" >0.425920</td>
#       <td id="T_88ebd_row0_col4" class="data row0 col4" >0.488649</td>
#       <td id="T_88ebd_row0_col5" class="data row0 col5" >0.368144</td>
#       <td id="T_88ebd_row0_col6" class="data row0 col6" >0.642719</td>
#     </tr>
#     <tr>
#       <th id="T_88ebd_level0_row1" class="row_heading level0 row1" >euribor3m_yeo_mms</th>
#       <td id="T_88ebd_row1_col0" class="data row1 col0" >0.978566</td>
#       <td id="T_88ebd_row1_col1" class="data row1 col1" >0.288846</td>
#       <td id="T_88ebd_row1_col2" class="data row1 col2" >0.254058</td>
#       <td id="T_88ebd_row1_col3" class="data row1 col3" >0.368909</td>
#       <td id="T_88ebd_row1_col4" class="data row1 col4" >0.859617</td>
#       <td id="T_88ebd_row1_col5" class="data row1 col5" >0.169744</td>
#       <td id="T_88ebd_row1_col6" class="data row1 col6" >0.987941</td>
#     </tr>
#     <tr>
#       <th id="T_88ebd_level0_